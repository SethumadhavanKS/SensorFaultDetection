# %%
print("hi")
# Out:
# hi

# %%
from src.sensor.logger import logging

# %%
logging.error("Test logger")

# %%
from src.sensor.exception import CustomException
import sys

# %%
try:
    1/0

except Exception as e:
    raise CustomException(e,sys)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 try:
# ----> 2     1/0
#       4 except Exception as e:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# CustomException                           Traceback (most recent call last)
# Cell In[11], line 5
#       2     1/0
#       4 except Exception as e:
# ----> 5     raise CustomException(e,sys)
#
# CustomException: (ZeroDivisionError('division by zero'), <module 'sys' (built-in)>)

# %%
import pandas as pd
import sys
from src.sensor.config import mongo_client
# Out:
# Loading environment variable from .env file
# Pinged your deployment. You successfully connected to MongoDB!

# %%
mydb = mongo_client["aps"]
mycol = mydb["sensor"]

# %%
json = mycol.find()

# %%
json

# %%
for i in json:
    print(i)
# Out:
# {'_id': ObjectId('6595ae59f5b597cf1339d577'), 'class': 'pos', 'aa_000': 153204, 'ab_000': '0', 'ac_000': '182', 'ad_000': 'na', 'ae_000': '0', 'af_000': '0', 'ag_000': '0', 'ag_001': '0', 'ag_002': '0', 'ag_003': '11804', 'ag_004': '684444', 'ag_005': '326536', 'ag_006': '31586', 'ag_007': '0', 'ag_008': '0', 'ag_009': '0', 'ah_000': '2658638', 'ai_000': '14346', 'aj_000': '0', 'ak_000': '0', 'al_000': '29384', 'am_0': '46356', 'an_000': '5566182', 'ao_000': '4426834', 'ap_000': '1571480', 'aq_000': '1120644', 'ar_000': '2', 'as_000': '0', 'at_000': '0', 'au_000': '0', 'av_000': '1368', 'ax_000': '862', 'ay_000': '0', 'ay_001': '0', 'ay_002': '0', 'ay_003': '0', 'ay_004': '0', 'ay_005': '0', 'ay_006': '0', 'ay_007': '94188', 'ay_008': '960182', 'ay_009': '0', 'az_000': '250', 'az_001': '16', 'az_002': '32', 'az_003': '146', 'az_004': '126', 'az_005': '951126', 'az_006': '91162', 'az_007': '11512', 'az_008': '0', 'az_009': '0', 'ba_000': '702994', 'ba_001': '186172', 'ba_002': '69282'
# ...

# %%
df = pd.DataFrame(list(json))

# %%
df
# Out:
#                             _id class  aa_000 ab_000      ac_000 ad_000  \
# 0      6595ae59f5b597cf1339ed0d   neg      32     na  2130706432     40
# 1      6595ae59f5b597cf1339ed0e   neg     732     na          na     na
# 2      6595ae59f5b597cf1339ed0f   neg   30936     na  2130706432    514
# 3      6595ae59f5b597cf1339ed10   neg  290958     na        4188    728
# 4      6595ae59f5b597cf1339ed11   neg   34742     na          na     na
# ...                         ...   ...     ...    ...         ...    ...
# 30145  6595ae65f5b597cf133a62ce   neg  153002     na         664    186
# 30146  6595ae65f5b597cf133a62cf   neg    2286     na  2130706538    224
# 30147  6595ae65f5b597cf133a62d0   neg     112      0  2130706432     18
# 30148  6595ae65f5b597cf133a62d1   neg   80292     na  2130706432    494
# 30149  6595ae65f5b597cf133a62d2   neg   40222     na         698    628
#
#       ae_000 af_000 ag_000 ag_001  ...   ee_002   ee_003   ee_004   ee_005  \
# ...

# %%
df.columns
# Out:
# Index(['_id', 'class', 'aa_000', 'ab_000', 'ac_000', 'ad_000', 'ae_000',
#        'af_000', 'ag_000', 'ag_001',
#        ...
#        'ee_002', 'ee_003', 'ee_004', 'ee_005', 'ee_006', 'ee_007', 'ee_008',
#        'ee_009', 'ef_000', 'eg_000'],
#       dtype='object', length=172)
